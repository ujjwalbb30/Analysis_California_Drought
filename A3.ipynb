# %%
# import pandas and numpy
import pandas as pd
import numpy as np

# %%
# importing california drought dataset
cal_drought_data = pd.read_csv('drought dataset/full_dataset_CA_sorted.csv')

# dropping the unnecessary column
cal_drought_data = cal_drought_data.drop(columns=['Unnamed: 0'])

# viewing first 5 and last 5 rows of dataset
print(cal_drought_data.head())
print(cal_drought_data.tail())
# Out:
#    fips        date  PRECTOT      PS  QV2M   T2M  T2MDEW  T2MWET  T2M_MAX  \
# 0  6001  2000-01-01     0.12   99.77  5.97  7.89    6.28    6.28    10.21
# 1  6001  2000-01-02     0.00  100.53  4.46  6.04    2.01    2.04    12.50
# 2  6001  2000-01-03     0.10  100.92  4.85  7.73    3.39    3.40    15.06
# 3  6001  2000-01-04     0.27  100.90  6.11  8.36    6.77    6.77    14.18
# 4  6001  2000-01-05     0.00  100.52  4.13  7.32    0.75    0.81    14.78
#
#    T2M_MIN  ...    TS  WS10M  WS10M_MAX  WS10M_MIN  WS10M_RANGE  WS50M  \
# 0     5.88  ...  7.72   3.01       5.03       0.46         4.57   4.55
# 1     0.92  ...  6.06   3.13       4.61       2.00         2.61   4.82
# 2     3.06  ...  7.67   2.42       3.43       1.36         2.07   3.39
# 3     5.66  ...  8.24   1.92       2.84       1.15         1.69   2.96
# 4     2.24  ...  7.13   4.56       7.48       2.70         4.79   6.94
#
#    WS50M_MAX  WS50M_MIN  WS50M_RANGE   score
# 0       8.58       0.76         7.82     NaN
# ...

# %%
# importing soil data
soil_data = pd.read_csv('drought dataset/soil_data.csv')
print(soil_data.head())
# Out:
#    fips        lat        lon  elevation  slope1  slope2  slope3  slope4  \
# 0  1001  32.536382 -86.644490         63  0.0419  0.2788  0.2984  0.2497
# 1  1005  31.870670 -85.405456        146  0.0158  0.1868  0.5441  0.2424
# 2  1003  30.659218 -87.746067         52  0.0746  0.4370  0.4415  0.0469
# 3  1007  33.015893 -87.127148         93  0.0144  0.1617  0.3714  0.3493
# 4  1009  33.977448 -86.567246        198  0.0050  0.0872  0.2799  0.3576
#
#    slope5  slope6  ...  CULTRF_LAND  CULTIR_LAND  CULT_LAND  SQ1  SQ2  SQ3  \
# 0  0.1142  0.0170  ...    56.293411     1.014811  57.308224    1    1    1
# 1  0.0106  0.0003  ...    72.578804     1.828159  74.406960    3    2    1
# 2  0.0000  0.0000  ...    59.843639     2.996914  62.840553    3    2    1
# 3  0.0898  0.0134  ...     1.916593     0.008330   1.924924    3    2    1
# 4  0.1477  0.1037  ...     1.891909     0.027488   1.919397    3    2    1
#
#    SQ4  SQ5  SQ6  SQ7
# 0    1    1    1    2
# 1    1    1    1    1
# ...

# %%
# viewing column names of the dataset
print(cal_drought_data.columns)
# viewing shape of the dataset
print(cal_drought_data.shape)
# Out:
# Index(['fips', 'date', 'PRECTOT', 'PS', 'QV2M', 'T2M', 'T2MDEW', 'T2MWET',
#        'T2M_MAX', 'T2M_MIN', 'T2M_RANGE', 'TS', 'WS10M', 'WS10M_MAX',
#        'WS10M_MIN', 'WS10M_RANGE', 'WS50M', 'WS50M_MAX', 'WS50M_MIN',
#        'WS50M_RANGE', 'score'],
#       dtype='object')
# (444918, 21)

# %%
# viewing summary statistics of the dataset
print(cal_drought_data.info())
#print(cal_drought_data.dtypes)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 444918 entries, 0 to 444917
# Data columns (total 21 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   fips         444918 non-null  int64
#  1   date         444918 non-null  object
#  2   PRECTOT      444918 non-null  float64
#  3   PS           444918 non-null  float64
#  4   QV2M         444918 non-null  float64
#  5   T2M          444918 non-null  float64
#  6   T2MDEW       444918 non-null  float64
#  7   T2MWET       444918 non-null  float64
#  8   T2M_MAX      444918 non-null  float64
#  9   T2M_MIN      444918 non-null  float64
#  10  T2M_RANGE    444918 non-null  float64
#  11  TS           444918 non-null  float64
#  12  WS10M        444918 non-null  float64
#  13  WS10M_MAX    444918 non-null  float64
#  14  WS10M_MIN    444918 non-null  float64
#  15  WS10M_RANGE  444918 non-null  float64
#  16  WS50M        444918 non-null  float64
# ...

# %%
print(cal_drought_data.describe())
# Out:
#                 fips        PRECTOT             PS           QV2M  \
# count  444918.000000  444918.000000  444918.000000  444918.000000
# mean     6058.000000       1.653038      94.040142       5.787296
# std        33.481376       5.582832       6.029655       1.926333
# min      6001.000000       0.000000      72.920000       0.520000
# 25%      6029.000000       0.000000      91.170000       4.390000
# 50%      6058.000000       0.010000      95.800000       5.770000
# 75%      6087.000000       0.270000      98.920000       7.140000
# max      6115.000000     127.600000     103.300000      17.940000
#
#                  T2M         T2MDEW         T2MWET        T2M_MAX  \
# count  444918.000000  444918.000000  444918.000000  444918.000000
# mean       14.275148       4.002170       4.044395      21.257976
# std         8.022038       5.678509       5.574274       9.773761
# min       -18.310000     -26.920000     -21.630000     -13.800000
# ...

# %%
# import matplotlib
import matplotlib.pyplot as plt

# %%
# plotting histograms of all the columns to see value distribution
cal_drought_data.hist(figsize=(20,20))
plt.show()

# %%
# plotting box and whiskers plot to view outliers
cal_drought_data.plot(kind='box',figsize=(200,10),subplots=True,sharex=False,sharey=False)
plt.show()

# %%
col_names = list(cal_drought_data.drop(columns=['fips','date','score']).columns)
print(col_names)
# Out:
# ['PRECTOT', 'PS', 'QV2M', 'T2M', 'T2MDEW', 'T2MWET', 'T2M_MAX', 'T2M_MIN', 'T2M_RANGE', 'TS', 'WS10M', 'WS10M_MAX', 'WS10M_MIN', 'WS10M_RANGE', 'WS50M', 'WS50M_MAX', 'WS50M_MIN', 'WS50M_RANGE']

# %%
fig, ax = plt.subplots(18,figsize=(30,100))
c = 0
for col in col_names:
    ax[c].scatter(x = cal_drought_data[col], y = cal_drought_data['score'])
    ax[c].set_xlabel(col)
    ax[c].set_ylabel("score")
    c = c+1
plt.show()

# %%
import seaborn as sns

# %%
sns.distplot(cal_drought_data['score'])

# %%
d1 = cal_drought_data[cal_drought_data['fips']==6001]
fig, ax = plt.subplots(figsize=(30,8))
sns.lineplot(x='date',y='score',data=d1)

# %%
col_n = list(cal_drought_data.drop(columns=['fips','date']).columns)
#print(col_names)
#for col in col_n:
#    sns.violinplot(y=cal_drought_data[col])
#    fig, ax = plt.subplots(18,figsize=(30,100))
fig, ax = plt.subplots(19,figsize=(5,95))
c = 0
for col in col_n:
    ax[c].violinplot(cal_drought_data[col])
    c = c+1
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\linalg\linalg.py:2116: RuntimeWarning: invalid value encountered in det
#   r = _umath_linalg.det(a, signature=signature)

# %%
import datetime

# %%
cal_drought_data['date'] = pd.to_datetime(cal_drought_data['date'])

# %%
fips_code = list(cal_drought_data.fips.unique())
print(fips_code)
print(len(fips_code))
# Out:
# [6001, 6003, 6005, 6007, 6009, 6011, 6013, 6015, 6017, 6019, 6021, 6023, 6025, 6027, 6029, 6031, 6033, 6035, 6037, 6039, 6041, 6043, 6045, 6047, 6049, 6051, 6053, 6055, 6057, 6059, 6061, 6063, 6065, 6067, 6069, 6071, 6073, 6075, 6077, 6079, 6081, 6083, 6085, 6087, 6089, 6091, 6093, 6095, 6097, 6099, 6101, 6103, 6105, 6107, 6109, 6111, 6113, 6115]
# 58

# %%
y = cal_drought_data[cal_drought_data.score.notnull()].score
print(y)
# Out:
# 3         0.6079
# 10        0.5036
# 17        0.0000
# 24        0.0000
# 31        0.0000
#            ...
# 444887    3.2744
# 444894    3.2744
# 444901    3.2744
# 444908    3.2744
# 444915    3.2744
# Name: score, Length: 63568, dtype: float64

# %%
l = list(y.index)
print(l)
# Out:
# [3, 10, 17, 24, 31, 38, 45, 52, 59, 66, 73, 80, 87, 94, 101, 108, 115, 122, 129, 136, 143, 150, 157, 164, 171, 178, 185, 192, 199, 206, 213, 220, 227, 234, 241, 248, 255, 262, 269, 276, 283, 290, 297, 304, 311, 318, 325, 332, 339, 346, 353, 360, 367, 374, 381, 388, 395, 402, 409, 416, 423, 430, 437, 444, 451, 458, 465, 472, 479, 486, 493, 500, 507, 514, 521, 528, 535, 542, 549, 556, 563, 570, 577, 584, 591, 598, 605, 612, 619, 626, 633, 640, 647, 654, 661, 668, 675, 682, 689, 696, 703, 710, 717, 724, 731, 738, 745, 752, 759, 766, 773, 780, 787, 794, 801, 808, 815, 822, 829, 836, 843, 850, 857, 864, 871, 878, 885, 892, 899, 906, 913, 920, 927, 934, 941, 948, 955, 962, 969, 976, 983, 990, 997, 1004, 1011, 1018, 1025, 1032, 1039, 1046, 1053, 1060, 1067, 1074, 1081, 1088, 1095, 1102, 1109, 1116, 1123, 1130, 1137, 1144, 1151, 1158, 1165, 1172, 1179, 1186, 1193, 1200, 1207, 1214, 1221, 1228, 1235, 1242, 1249, 1256, 1263, 1270, 1277, 1284, 1291, 1298, 1305, 1312, 1319, 1326, 1333, 1340, 134
# ...

# %%
r = round(len(cal_drought_data[cal_drought_data['fips']==6001])/7)
print(r)
# Out:
# 1096

# %%
df3 = pd.DataFrame([])
for fips in fips_code:
    df1 = cal_drought_data[cal_drought_data['fips']==fips].reset_index(drop=True)
    df2 = df1.drop(columns = ['date','score'])
    for i in range(r):
        if ((7*(i+1))+3-90)<0:
            agg_data = pd.DataFrame(df2[0:((7*(i+1))+3)].agg("mean",axis="rows"))
            df3 = df3.append(agg_data.transpose())
        else:
            agg_data = pd.DataFrame(df2[((7*(i+1))+3-90):((7*(i+1)+3))].agg("mean",axis="rows"))
            df3 = df3.append(agg_data.transpose())

# %%
print(df3)
print(len(df3))
# Out:
#       fips   PRECTOT          PS      QV2M        T2M    T2MDEW    T2MWET  \
# 0   6001.0  0.196000  100.487000  5.158000   7.692000  3.782000  3.810000
# 0   6001.0  1.709412  100.257059  5.701765   8.592941  5.245294  5.262941
# 0   6001.0  5.068333  100.105833  6.274583   9.290833  6.589167  6.601667
# 0   6001.0  4.312581  100.076129  6.227097   9.242903  6.543226  6.553871
# 0   6001.0  3.762632  100.067105  6.358947   9.557368  6.895263  6.903947
# ..     ...       ...         ...       ...        ...       ...       ...
# 0   6115.0  0.586000   95.797222  3.967889  16.987444 -0.969000 -0.422778
# 0   6115.0  1.059778   95.826000  3.981444  15.774889 -0.911556 -0.120444
# 0   6115.0  1.363333   95.881111  3.865667  14.584333 -1.221556 -0.182556
# 0   6115.0  1.706778   95.900556  3.775444  13.172000 -1.462889 -0.192333
# 0   6115.0  1.894186   95.929302  3.846860  11.910581 -1.190465  0.204419
#
#       T2M_MAX    T2M_MIN  T2M_RANGE         TS     WS10M  WS10M_MAX  \
# ...

# %%
df_score = list(y)
df3['score'] = df_score
#df3 = df3.drop(columns=['Unnamed: 0'])
print(df3)
# Out:
#       fips   PRECTOT          PS      QV2M        T2M    T2MDEW    T2MWET  \
# 0   6001.0  0.196000  100.487000  5.158000   7.692000  3.782000  3.810000
# 0   6001.0  1.709412  100.257059  5.701765   8.592941  5.245294  5.262941
# 0   6001.0  5.068333  100.105833  6.274583   9.290833  6.589167  6.601667
# 0   6001.0  4.312581  100.076129  6.227097   9.242903  6.543226  6.553871
# 0   6001.0  3.762632  100.067105  6.358947   9.557368  6.895263  6.903947
# ..     ...       ...         ...       ...        ...       ...       ...
# 0   6115.0  0.586000   95.797222  3.967889  16.987444 -0.969000 -0.422778
# 0   6115.0  1.059778   95.826000  3.981444  15.774889 -0.911556 -0.120444
# 0   6115.0  1.363333   95.881111  3.865667  14.584333 -1.221556 -0.182556
# 0   6115.0  1.706778   95.900556  3.775444  13.172000 -1.462889 -0.192333
# 0   6115.0  1.894186   95.929302  3.846860  11.910581 -1.190465  0.204419
#
#       T2M_MAX    T2M_MIN  T2M_RANGE         TS     WS10M  WS10M_MAX  \
# ...

# %%
df3.to_csv('drought dataset/ninety_days_aggregated_data_ca_drought.csv')

# %%
data = df3.drop(columns=['fips'])
data_corr = data.corr()
print(data_corr)
# Out:
#               PRECTOT        PS      QV2M       T2M    T2MDEW    T2MWET  \
# PRECTOT      1.000000 -0.048007 -0.204288 -0.666130 -0.146719 -0.151690
# PS          -0.048007  1.000000  0.616927  0.331619  0.755998  0.759470
# QV2M        -0.204288  0.616927  1.000000  0.506584  0.972135  0.972155
# T2M         -0.666130  0.331619  0.506584  1.000000  0.489889  0.493620
# T2MDEW      -0.146719  0.755998  0.972135  0.489889  1.000000  0.999557
# T2MWET      -0.151690  0.759470  0.972155  0.493620  0.999557  1.000000
# T2M_MAX     -0.701349  0.259487  0.411447  0.983864  0.395706  0.399436
# T2M_MIN     -0.606137  0.442801  0.601190  0.974832  0.589823  0.593798
# T2M_RANGE   -0.633563 -0.099579 -0.003659  0.698454 -0.021297 -0.019076
# TS          -0.660300  0.341604  0.530653  0.995229  0.512305  0.515838
# WS10M       -0.124301  0.359713  0.313631  0.078592  0.324374  0.327566
# WS10M_MAX   -0.238329  0.277126  0.264030  0.188088  0.259103  0.262540
# ...

# %%
ax = sns.heatmap(data_corr,vmin=-1,vmax=1,center=0,cmap=sns.diverging_palette(20,220,n=200),square=True)

# %% [markdown]
# https://www.kaggle.com/pmarcelino/comprehensive-data-exploration-with-python
#
# https://machinelearningmastery.com/time-series-data-visualization-with-python/
#
# https://www.kaggle.com/sharp1/how-to-plot-violin-plot-in-expressive-manner
#
# https://www.marsja.se/how-to-make-a-violin-plot-in-python-using-matplotlib-and-seaborn/
